# %% [markdown]
# # Run fitting as a batch job -- fish dataset / MAP estimation

# %%
import numpy as np
import pandas as pd

from myconfig import DATASET_DIR, DATA_DIR

# %%
conditions = pd.read_csv('conditions-main.tsv', sep='\t')

# %%
root_seed = 732198749832
colaml = 'singularity exec -B $(readlink -v data) singularity/sif/jupyter+colaml.6c01617 colaml'
cmd_template = dict(
    mmm    = '{colaml} fit {model} -i {infile} -o {outfile} --lmax {lmax} --ncat {ncat} --seed {seed} -q --map', 
    mirage = '{colaml} fit {model} -i {infile} -o {outfile} --lmax {lmax} --nmixt {nmixt} --seed {seed} -q --map',
    branch = '{colaml} fit {model} -i {infile} -o {outfile} --lmax {lmax} --seed {seed} -q --map', 
)

with open('240717-batch-job-array-fish-map.txt', 'wt') as file:
    print('conditionID', 'fold', 'fit_rep', 'model', 'lmax', 'nmixt', 'ncat', 'seed', 'infile', 'outfile', 'cmd', file=file, sep='\t')    
    for cidx, conditionID, model, lmax, nmixt, ncat in conditions.itertuples():
        for fold in range(1, 6):
            rng = np.random.default_rng([root_seed, cidx, fold])
            for fit_rep, seed in enumerate(rng.integers(1, 2**16, size=10), start=1):
                infile  = f'datasets/03-fish/cv5/fish-lmax{lmax}-train{fold}-v0.json.gz'
                outfile = f'data/batch/03-fish-map/{conditionID}/{conditionID}-train{fold}.{fit_rep:02d}.json.gz'
                cmd = cmd_template[model].format(
                    colaml  = colaml , 
                    model   = model  , 
                    lmax    = lmax   , 
                    nmixt   = nmixt  ,
                    ncat    = ncat   ,
                    seed    = seed   , 
                    infile  = infile , 
                    outfile = outfile
                )
                print(conditionID, fold, fit_rep, model, lmax, nmixt, ncat, seed, infile, outfile, cmd, file=file, sep='\t')

# %%
pd.read_csv('240717-batch-job-array-fish-map.txt', sep='\t')
# Out:
#      conditionID  fold  fit_rep   model  lmax  nmixt  ncat   seed  \
# 0         cond01     1        1     mmm     2     -1     1  56790
# 1         cond01     1        2     mmm     2     -1     1  46944
# 2         cond01     1        3     mmm     2     -1     1  35323
# 3         cond01     1        4     mmm     2     -1     1  63411
# 4         cond01     1        5     mmm     2     -1     1  21308
# ...          ...   ...      ...     ...   ...    ...   ...    ...
# 1145      cond23     5        6  branch     3     -1    -1  43975
# 1146      cond23     5        7  branch     3     -1    -1  18542
# 1147      cond23     5        8  branch     3     -1    -1  35350
# 1148      cond23     5        9  branch     3     -1    -1   6235
# 1149      cond23     5       10  branch     3     -1    -1    134
#
#                                                  infile  \
# 0     datasets/03-fish/cv5/fish-lmax2-train1-v0.json.gz
# 1     datasets/03-fish/cv5/fish-lmax2-train1-v0.json.gz
# 2     datasets/03-fish/cv5/fish-lmax2-train1-v0.json.gz
# 3     datasets/03-fish/cv5/fish-lmax2-train1-v0.json.gz
# 4     datasets/03-fish/cv5/fish-lmax2-train1-v0.json.gz
# ...                                                 ...
# 1145  datasets/03-fish/cv5/fish-lmax3-train5-v0.json.gz
# 1146  datasets/03-fish/cv5/fish-lmax3-train5-v0.json.gz
# 1147  datasets/03-fish/cv5/fish-lmax3-train5-v0.json.gz
# 1148  datasets/03-fish/cv5/fish-lmax3-train5-v0.json.gz
# 1149  datasets/03-fish/cv5/fish-lmax3-train5-v0.json.gz
#
#                                                 outfile  \
# 0     data/batch/03-fish-map/cond01/cond01-train1.01...
# 1     data/batch/03-fish-map/cond01/cond01-train1.02...
# 2     data/batch/03-fish-map/cond01/cond01-train1.03...
# 3     data/batch/03-fish-map/cond01/cond01-train1.04...
# 4     data/batch/03-fish-map/cond01/cond01-train1.05...
# ...                                                 ...
# 1145  data/batch/03-fish-map/cond23/cond23-train5.06...
# 1146  data/batch/03-fish-map/cond23/cond23-train5.07...
# 1147  data/batch/03-fish-map/cond23/cond23-train5.08...
# 1148  data/batch/03-fish-map/cond23/cond23-train5.09...
# 1149  data/batch/03-fish-map/cond23/cond23-train5.10...
#
#                                                     cmd
# 0     singularity exec -B $(readlink -v data) singul...
# 1     singularity exec -B $(readlink -v data) singul...
# 2     singularity exec -B $(readlink -v data) singul...
# 3     singularity exec -B $(readlink -v data) singul...
# 4     singularity exec -B $(readlink -v data) singul...
# ...                                                 ...
# 1145  singularity exec -B $(readlink -v data) singul...
# 1146  singularity exec -B $(readlink -v data) singul...
# 1147  singularity exec -B $(readlink -v data) singul...
# 1148  singularity exec -B $(readlink -v data) singul...
# 1149  singularity exec -B $(readlink -v data) singul...
#
# [1150 rows x 11 columns]

# %%
# !head -n-0 240717-fitting-sbatch*.sh
# Out:
# ==> 240717-fitting-sbatch3map.sh <==
# #!/bin/bash
# #SBATCH --array 1-150%60
# #SBATCH --output data/batch/03-fish-map/log/%x.stdxxx-%3a
# set -eu -o pipefail
# export OPENBLAS_NUM_THREADS=1 MKL_NUM_THREADS=1 OMP_NUM_THREADS=1 VECLIB_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1
#
# cd $SLURM_SUBMIT_DIR
# eval `awk -v ARRAYID=$(( $SLURM_ARRAY_TASK_ID+1 )) -F "\t" 'NR==ARRAYID {print $NF}' notebooks/fit-to-real-data/240717-batch-job-array-fish-map.txt`
#
# ==> 240717-fitting-sbatch4map.sh <==
# #!/bin/bash
# #SBATCH --array 1-1000%80
# #SBATCH --output data/batch/03-fish-map/log/%x.stdxxx-%3a
# set -eu -o pipefail
# export OPENBLAS_NUM_THREADS=1 MKL_NUM_THREADS=1 OMP_NUM_THREADS=1 VECLIB_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1
#
# cd $SLURM_SUBMIT_DIR
# eval `awk -v ARRAYID=$(( $SLURM_ARRAY_TASK_ID+151 )) -F "\t" 'NR==ARRAYID {print $NF}' notebooks/fit-to-real-data/240717-batch-job-array-fish-map.txt`

# %% [markdown]
# Run outside this singularity image (@top level):
#
# `sbatch notebooks/fit-to-real-data/240717-fitting-sbatch3map.sh`
# `sbatch notebooks/fit-to-real-data/240717-fitting-sbatch4map.sh`

# %%
# remove empty log files
# !find {DATA_DIR}/batch/03-fish-map/log -type f -empty -delete
